# %%
from ksif import Portfolio
# Out:
# c:\python\venv\notebook\lib\site-packages\ksif\core\frame.py:23: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import MultiIndex

# %%
pf = Portfolio()
# Out:
# ...
# 2020-09-25_company is saved as data/2020-09-25_company.pck.

# %%
pf
# Out:
#            code     code02 firmname      mdate       date       size  \
# 0       A000020  A000020_0     동화약품 2002-04-30 2002-04-30  17.615261
# 1       A000020  A000020_0     동화약품 2002-05-31 2002-05-31  17.610258
# 2       A000020  A000020_0     동화약품 2002-06-30 2002-06-28  17.516838
# 3       A000020  A000020_0     동화약품 2002-07-31 2002-07-31  17.544043
# 4       A000020  A000020_0     동화약품 2002-08-31 2002-08-30  17.541350
# ...         ...        ...      ...        ...        ...        ...
# 355276  A950160  A950160_0   코오롱티슈진 2020-07-31 2020-07-31  20.009000
# 355277  A950160  A950160_0   코오롱티슈진 2020-08-31 2020-08-31  20.009000
# 355278  A950160  A950160_0   코오롱티슈진 2020-09-30 2020-09-25  20.009000
# 355279  A950190  A950190_0      미투젠 2020-08-31 2020-08-31  19.938644
# 355280  A950190  A950190_0      미투젠 2020-09-30 2020-09-25  19.675148
#
#              e_p       b_p       s_p      gp_p  ...  fin_score_24  \
# 0       0.139536  3.002092  2.733069  1.097341  ...           NaN
# ...
